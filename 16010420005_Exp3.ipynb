# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data = pd.read_csv("/content/Sample-data.csv")
first_column = data.iloc[:, 0]
first_column = first_column.astype(str)
combined_text = " ".join(first_column)
tokens = [word for word in word_tokenize(combined_text) if word.isalpha()]
tokens = tokens[:5000]
print(tokens)
# Out:
# ['The', 'older', 'you', 'get', 'the', 'less', 'people', 'you', 'trust', 'i', 'dont', 'have', 'time', 'to', 'hate', 'anyone', 'ill', 'just', 'forget', 'about', 'you', 'Never', 'waste', 'your', 'feelings', 'on', 'people', 'who', 'do', 'value', 'them', 'No', 'relationship', 'is', 'ever', 'a', 'waste', 'of', 'time', 'If', 'it', 'did', 'bring', 'you', 'what', 'you', 'want', 'it', 'taught', 'you', 'what', 'you', 'do', 'want', 'When', 'your', 'girlfriend', 'breaks', 'your', 'heart', 'do', 'say', 'a', 'word', 'just', 'smile', 'because', 'she', 'gives', 'you', 'the', 'opportunity', 'to', 'find', 'someone', 'better', 'than', 'her', 'Stop', 'overthinking', 'Relax', 'and', 'let', 'it', 'go', 'i', 'hope', 'in', 'this', 'messed', 'up', 'world', 'you', 'find', 'someone', 'who', 'makes', 'you', 'forget', 'about', 'it', 'all', 'someone', 'who', 'genuinely', 'makes', 'you', 'smile', 'every', 'single', 'day', 'Life', 'does', 'give', 'you', 'what', 'you', 'want', 'It', 'gives', 'you', 'what', 'you', 'work', 'for', 'If', 'you', 'love', 'someone', 'then', 'you', 'need', 'to', 'support', 'them', 'Treat', 'me', 'right', 'and', 'I', 'treat', 'you', 'even', 'better', 'Explaining', 'your', 'feelings', 'to', 'someone', 'is', 'never', 'easy', 'Real', 'friends', 'do', 'keep', 'secrets', 'from', 'each', 'other', 'No', 'matter', 'how', 'busy', 'a', 'person', 'is', 'if', 'they', 'care', 'they', 'find', 'time', 'for', 'you', 'Life', 'is', 'too', 'short', 'to', 'worry', 'about', 'stupid', 'things', 'Have', 'fun', 'Fall', 'in', 'love', 'Regret', 'nothing', 'and', 'do', 'let', 'people', 'bring', 'you', 'down', 'People', 'are', 'always', 'gon', 'na', 'be', 'there', 'for', 'you', 'That', 'why', 'you', 'learn', 'to', 'handle', 'things', 'on', 'your', 'own', 'Respect', 'yourself', 'enough', 'to', 'walk', 'away', 'from', 'anything', 'that', 'no', 'longer', 'makes', 'you', 'happy', 'Brushing', 'your', 'teeth', 'is', 'the', 'only', 'time', 'you', 'clean', 'your', 'skeleton', 'Choose', 'to', 'look', 'on', 'the', 'bright', 'side', 'True', 'love', 'and', 'loyal', 'friends', 'are', 'two', 'of', 'the', 'hardest', 'things', 'to', 'find', 'Your', 'mistakes', 'should', 'be', 'your', 'motivation', 'not', 'your', 'excuses', 'There', 'always', 'that', 'one', 'special', 'person', 'that', 'no', 'matter', 'what', 'they', 'done', 'to', 'you', 'you', 'still', 'just', 'ca', 'let', 'them', 'go', 'The', 'only', 'thing', 'making', 'you', 'unhappy', 'are', 'your', 'own', 'thoughts', 'Change', 'them', 'Life', 'is', 'better', 'when', 'you', 'laughing', 'My', 'attitude', 'is', 'like', 'a', 'book', 'many', 'can', 'read', 'but', 'few', 'can', 'understand', 'Cleanse', 'your', 'mind', 'of', 'all', 'bad', 'vibes', 'and', 'let', 'the', 'good', 'vibes', 'flow', 'in', 'Dear', 'parents', 'i', 'make', 'you', 'proud', 'someday', 'One', 'positive', 'change', 'every', 'day', 'will', 'change', 'your', 'life', 'i', 'want', 'US', 'until', 'the', 'end', 'Accept', 'your', 'past', 'without', 'regret', 'handle', 'your', 'present', 'with', 'confidence', 'and', 'face', 'your', 'future', 'without', 'fear', 'Karma', 'has', 'no', 'menu', 'You', 'get', 'served', 'what', 'you', 'deserve', 'I', 'do', 'cry', 'in', 'front', 'of', 'people', 'but', 'if', 'I', 'do', 'just', 'know', 'that', 'I', 'truly', 'hurting', 'It', 'crazy', 'how', 'fast', 'things', 'can', 'change', 'Sometimes', 'you', 'just', 'need', 'a', 'break', 'to', 'be', 'alone', 'and', 'to', 'figure', 'everything', 'out', 'Work', 'hard', 'stay', 'positive', 'and', 'good', 'things', 'will', 'happen', 'My', 'friendships', 'are', 'so', 'important', 'to', 'me', 'if', 'you', 'my', 'real', 'friend', 'you', 'my', 'family', 'Happiness', 'is', 'the', 'best', 'revenge', 'Dear', 'God', 'no', 'matter', 'what', 'is', 'going', 'on', 'in', 'my', 'life', 'I', 'thank', 'you', 'for', 'the', 'privilege', 'of', 'being', 'alive', 'today', 'Do', 'what', 'makes', 'you', 'happy', 'and', 'be', 'with', 'who', 'makes', 'you', 'smile', 'Believe', 'in', 'yourself', 'Always', 'You', 'smile', 'b ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for token in tokens:
  print(token,"--->", porter.stem(token))
# Out:
# The ---> the
# older ---> older
# you ---> you
# get ---> get
# the ---> the
# less ---> less
# people ---> peopl
# you ---> you
# trust ---> trust
# i ---> i
# dont ---> dont
# have ---> have
# time ---> time
# to ---> to
# hate ---> hate
# anyone ---> anyon
# ill ---> ill
# just ---> just
# forget ---> forget
# about ---> about
# you ---> you
# Never ---> never
# waste ---> wast
# your ---> your
# feelings ---> feel
# on ---> on
# people ---> peopl
# who ---> who
# do ---> do
# value ---> valu
# them ---> them
# No ---> no
# relationship ---> relationship
# is ---> is
# ever ---> ever
# a ---> a
# waste ---> wast
# of ---> of
# time ---> time
# If ---> if
# it ---> it
# did ---> did
# bring ---> bring
# you ---> you
# what ---> what
# you ---> you
# want ---> want
# it ---> it
# taught ---> taught
# you ---> you
# what ---> what
# you ---> you
# do ---> do
# want ---> want
# When ---> when
# your ---> your
# girlfriend ---> girlfriend
# breaks ---> break
# your ---> your
# heart ---> heart
# do ---> do
# say ---> say
# a ---> a
# word ---> word
# just ---> just
# smile ---> smile
# because ---> becaus
# she ---> she
# gives ---> give
# you ---> you
# the ---> the
# opportunity ---> opportun
# to ---> to
# find ---> find
# someone ---> someon
# better ---> better
# than ---> than
# her ---> her
# Stop ---> stop
# overthinking ---> overthink
# Relax ---> relax
# and ---> and
# let ---> let
# it ---> it
# go ---> go
# i ---> i
# hope ---> hope
# in ---> in
# this ---> thi
# messed ---> mess
# up ---> up
# world ---> world
# you ---> you
# find ---> find
# someone ---> someon
# who ---> who
# makes ---> make
# you ---> you
# forget ---> forget
# about ---> about
# it ---> it
# all ---> all
# someone ---> someon
# who ---> who
# genuinely ---> genuin
# makes ---> make
# you ---> you
# smile ---> smile
# every ---> everi
# single ---> singl
# day ---> day
# Life ---> life
# does ---> doe
# give ---> give
# you ---> you
# what ---> what
# you ---> you
# want ---> want
# It ---> it
# gives ---> give
# you ---> you
# what ---> what
# you ---> you
# work ---> work
# for ---> for
# If ---> if
# you ---> you
# love ---> love
# someone ---> someon
# then ---> then
# you ---> you
# need ---> need
# to ---> to
# support ---> support
# them ---> them
# Treat ---> treat
# me ---> me
# right ---> right
# and ---> and
# I ---> i
# treat ---> treat
# you ---> you
# even ---> even
# better ---> better
# Explaining ---> explain
# your ---> your
# feelings ---> feel
# to ---> to
# someone ---> someon
# is ---> is
# never ---> never
# easy ---> easi
# Real ---> real
# friends ---> friend
# do ---> do
# keep ---> keep
# secrets ---> secret
# from ---> from
# each ---> each
# other ---> other
# No ---> no
# matter ---> matter
# how ---> how
# busy ---> busi
# a ---> a
# person ---> person
# is ---> is
# if ---> if
# they ---> they
# care ---> care
# they ---> they
# find ---> find
# time ---> time
# for ---> for
# you ---> you
# Life ---> life
# is ---> is
# too ---> too
# short ---> short
# to ---> to
# worry ---> worri
# about ---> about
# stupid ---> stupid
# things ---> thing
# Have ---> have
# fun ---> fun
# Fall ---> fall
# in ---> in
# love ---> love
# Regret ---> regret
# nothing ---> noth
# and ---> and
# do ---> do
# let ---> let
# people ---> peopl
# bring ---> bring
# you ---> you
# down ---> down
# People ---> peopl
# are ---> are
# always ---> alway
# gon ---> gon
# na ---> na
# be ---> be
# there ---> there
# for ---> for
# you ---> you
# That ---> that
# why ---> whi
# you ---> you
# learn ---> learn
# to ---> to
# handle ---> handl
# things ---> thing
# on ---> on
# your ---> your
# own ---> own
# Respect ---> respect
# yourself ---> yourself
# enough ---> enough
# to ---> to
# walk ---> walk
# away ---> away
# from ---> from
# anything ---> anyth
# that ---> that
# no ---> no
# longer ---> longer
# makes ---> make
# you ---> you
# happy ---> happi
# Brushing ---> brush
# your ---> your
# teeth ---> teeth
# is ---> is
# the ---> the
# only ---> onli
# time ---> time
# you ---> you
# clean ---> clean
# your ---> your
# skeleton ---> skeleton
# Choose ---> choos
# to ---> to
# look ---> look
# on ---> on
# the ---> the
# bright ---> bright
# side ---> side
# True ---> true
# love ---> love
# and ---> and
# loyal ---> loyal
# friends ---> friend
# are ---> are
# two ---> two
# of ---> of
# the ---> the
# hardest ---> hardest
# things ---> thing
# to ---> to
# find ---> find
# Your ---> your
# mistakes ---> mistak
# should ---> should
# be ---> be
# your ---> your
# motivation ---> motiv
# not ---> not
# your ---> your
# excuses ---> excus
# There ---> there
# always ---> alway
# that ---> that
# one ---> one
# special ---> special
# person ---> person
# that ---> that
# no ---> no
# matter ---> matter
# what ---> what
# they ---> they
# done ---> done
# to ---> to
# you ---> you
# you ---> you
# still ---> still
# just ---> just
# ca ---> ca
# let ---> let
# them ---> them
# go ---> go
# The ---> the
# only ---> onli
# thing ---> thing
# making ---> make
# you ---> you
# unhappy ---> unhappi
# are ---> are
# your ---> your
# own ---> own
# thoughts ---> thought
# Change ---> chang
# them ---> them
# Life ---> life
# is ---> is
# better ---> better
# when ---> when
# you ---> you
# laughing ---> laugh
# My ---> my
# attitude ---> attitud
# is ---> is
# like ---> like
# a ---> a
# book ---> book
# many ---> mani
# can ---> can
# read ---> read
# but ---> but
# few ---> few
# can ---> can
# understand ---> understand
# Cleanse ---> cleans
# your ---> your
# mind ---> mind
# of ---> of
# all ---> all
# bad ---> bad
# vibes ---> vibe
# and ---> and
# let ---> let
# the ---> the
# good ---> good
# vibes ---> vibe
# flow ---> flow
# in ---> in
# Dear ---> dear
# parents ---> parent
# i ---> i
# make ---> make
# you ---> you
# proud ---> proud
# someday ---> someday
# One ---> one
# positive ---> posit
# change ---> chang
# every ---> everi
# day ---> day
# will ---> will
# change ---> chang
# your ---> your
# life ---> life
# i ---> i
# want ---> want
# US ---> us
# until ---> until
# the ---> the
# end ---> end
# Accept ---> accept
# your ---> your
# past ---> past
# without ---> without
# regret ---> regret
# handle ---> handl
# your ---> your
# present ---> present
# with ---> with
# confidence ---> confid
# and ---> and
# face ---> face
# your ---> your
# future ---> futur
# without ---> without
# fear ---> fear
# Karma ---> karma
# has ---> ha
# no ---> no
# menu ---> menu
# You ---> you
# get ---> get
# served ---> serv
# what ---> what
# you ---> you
# deserve ---> deserv
# I ---> i
# do ---> do
# cry ---> cri
# in ---> in
# front ---> front
# of ---> of
# people ---> peopl
# but ---> but
# if ---> if
# I ---> i
# do ---> do
# just ---> just
# know ---> know
# that ---> that
# I ---> i
# truly ---> truli
# hurting ---> hurt
# It ---> it
# crazy ---> crazi
# how ---> how
# fast ---> fast
# things ---> thing
# can ---> can
# change ---> chang
# Sometimes ---> sometim
# you ---> you
# just ---> just
# need ---> need
# a ---> a
# break ---> break
# to ---> to
# be ---> be
# alone ---> alon
# and ---> and
# to ---> to
# figure ---> figur
# everything ---> everyth
# out ---> out
# Work ---> work
# hard ---> hard
# stay ---> stay
# positive ---> posit
# and ---> and
# good ---> good
# things ---> thing
# will ---> will
# happen ---> happen
# My ---> my
# friendships ---> friendship
# are ---> are
# so ---> so
# important ---> import
# to ---> to
# me ---> me
# if ---> if
# you ---> you
# my ---> my
# real ---> real
# friend ---> friend
# you ---> you
# my ---> my
# family ---> famili
# Happiness ---> happi
# is ---> is
# the ---> the
# best ---> best
# revenge ---> reveng
# Dear ---> dear
# God ---> god
# no ---> no
# matter ---> matter
# what ---> what
# is ---> is
# going ---> go
# on ---> on
# in ---> in
# my ---> my
# life ---> life
# I ---> i
# thank ---> thank
# you ---> you
# for ---> for
# the ---> the
# privilege ---> privileg
# of ---> of
# being ---> be
# alive ---> aliv
# today ---> today
# Do ---> do
# what ---> what
# makes ---> make
# you ---> you
# happy ---> happi
# and ---> and
# be ---> be
# with ---> with
# who ---> who
# makes ---> make
# you ---> you
# smile ---> smile
# Believe ---> believ
# in ---> in
# yourself ---> yourself
# Always ---> alway
# You ---> you
# smile ---> smile
# but ---> but
# you ---> you
# wan ---> wan
# na ---> na
# cry ---> cri
# You ---> you
# talk ---> talk
# but ---> but
# you ---> you
# wan ---> wan
# na ---> na
# be ---> be
# quiet ---> quiet
# You ---> you
# pretend ---> pretend
# like ---> like
# you ---> you
# happy ---> happi
# but ---> but
# you ---> you
# are ---> are
# Just ---> just
# because ---> becaus
# someone ---> someon
# does ---> doe
# react ---> react
# it ---> it
# does ---> doe
# mean ---> mean
# they ---> they
# do ---> do
# notice ---> notic
# It ---> it
# hard ---> hard
# to ---> to
# forget ---> forget
# someone ---> someon
# who ---> who
# gave ---> gave
# you ---> you
# so ---> so
# much ---> much
# to ---> to
# remember ---> rememb
# I ---> i
# ca ---> ca
# promise ---> promis
# you ---> you
# complete ---> complet
# happiness ---> happi
# because ---> becaus
# with ---> with
# true ---> true
# love ---> love
# there ---> there
# comes ---> come
# a ---> a
# pain ---> pain
# thank ---> thank
# God ---> god
# for ---> for
# the ---> the
# friends ---> friend
# that ---> that
# actually ---> actual
# care ---> care
# about ---> about
# me ---> me
# check ---> check
# on ---> on
# me ---> me
# you ---> you
# guys ---> guy
# know ---> know
# who ---> who
# you ---> you
# are ---> are
# you ---> you
# a ---> a
# blessing ---> bless
# i ---> i
# swear ---> swear
# Stop ---> stop
# crying ---> cri
# over ---> over
# yesterday ---> yesterday
# and ---> and
# start ---> start
# smiling ---> smile
# for ---> for
# tomorrow ---> tomorrow
# You ---> you
# do ---> do
# need ---> need
# anybody ---> anybodi
# to ---> to
# tell ---> tell
# you ---> you
# who ---> who
# you ---> you
# are ---> are
# or ---> or
# what ---> what
# you ---> you
# are ---> are
# You ---> you
# are ---> are
# what ---> what
# you ---> you
# are ---> are
# Never ---> never
# judge ---> judg
# someone ---> someon
# everyone ---> everyon
# has ---> ha
# a ---> a
# story ---> stori
# With ---> with
# random ---> random
# people ---> peopl
# I ---> i
# shy ---> shi
# With ---> with
# my ---> my
# best ---> best
# friends ---> friend
# I ---> i
# crazy ---> crazi
# Everybody ---> everybodi
# has ---> ha
# gone ---> gone
# through ---> through
# something ---> someth
# that ---> that
# has ---> ha
# changed ---> chang
# them ---> them
# in ---> in
# a ---> a
# way ---> way
# that ---> that
# they ---> they
# could ---> could
# never ---> never
# go ---> go
# back ---> back
# to ---> to
# the ---> the
# person ---> person
# they ---> they
# once ---> onc
# were ---> were
# Count ---> count
# your ---> your
# blessings ---> bless
# instead ---> instead
# of ---> of
# your ---> your
# problems ---> problem
# I ---> i
# just ---> just
# wan ---> wan
# na ---> na
# travel ---> travel
# the ---> the
# world ---> world
# the ---> the
# what ---> what
# ifs ---> if
# and ---> and
# should ---> should
# haves ---> have
# will ---> will
# eat ---> eat
# you ---> you
# alive ---> aliv
# My ---> my
# silence ---> silenc
# is ---> is
# my ---> my
# expression ---> express
# of ---> of
# my ---> my
# pain ---> pain
# If ---> if
# I ---> i
# stop ---> stop
# caring ---> care
# will ---> will
# you ---> you
# start ---> start
# caring ---> care
# Girls ---> girl
# notice ---> notic
# EVERYTHING ---> everyth
# From ---> from
# your ---> your
# change ---> chang
# of ---> of
# emotion ---> emot
# in ---> in
# texts ---> text
# to ---> to
# your ---> your
# short ---> short
# responses ---> respons
# always ---> alway
# giving ---> give
# reasons ---> reason
# not ---> not
# to ---> to
# hangout ---> hangout
# We ---> we
# notice ---> notic
# Every ---> everi
# day ---> day
# may ---> may
# not ---> not
# be ---> be
# good ---> good
# but ---> but
# there ---> there
# is ---> is
# something ---> someth
# good ---> good
# in ---> in
# every ---> everi
# day ---> day
# World ---> world
# shortest ---> shortest
# horror ---> horror
# story ---> stori
# consists ---> consist
# of ---> of
# only ---> onli
# two ---> two
# sentences ---> sentenc
# The ---> the
# last ---> last
# man ---> man
# on ---> on
# Earth ---> earth
# sat ---> sat
# alone ---> alon
# in ---> in
# a ---> a
# room ---> room
# There ---> there
# was ---> wa
# a ---> a
# knock ---> knock
# on ---> on
# the ---> the
# door ---> door
# Your ---> your
# first ---> first
# instinct ---> instinct
# is ---> is
# always ---> alway
# right ---> right
# So ---> so
# always ---> alway
# go ---> go
# with ---> with
# your ---> your
# first ---> first
# instinct ---> instinct
# Even ---> even
# if ---> if
# it ---> it
# a ---> a
# bad ---> bad
# idea ---> idea
# Because ---> becaus
# bad ---> bad
# ideas ---> idea
# make ---> make
# good ---> good
# stories ---> stori
# my ---> my
# entire ---> entir
# life ---> life
# is ---> is
# basically ---> basic
# a ---> a
# Rihanna ---> rihanna
# song ---> song
# like ---> like
# all ---> all
# I ---> i
# do ---> do
# is ---> is
# work ---> work
# work ---> work
# work ---> work
# work ---> work
# and ---> and
# the ---> the
# rest ---> rest
# I ---> i
# have ---> have
# no ---> no
# idea ---> idea
# what ---> what
# the ---> the
# fuck ---> fuck
# is ---> is
# going ---> go
# on ---> on
# A ---> a
# negative ---> neg
# mind ---> mind
# will ---> will
# never ---> never
# give ---> give
# you ---> you
# a ---> a
# positive ---> posit
# life ---> life
# Psychology ---> psycholog
# says ---> say
# It ---> it
# not ---> not
# the ---> the
# song ---> song
# makes ---> make
# you ---> you
# emotional ---> emot
# it ---> it
# the ---> the
# people ---> peopl
# and ---> and
# things ---> thing
# that ---> that
# come ---> come
# to ---> to
# your ---> your
# mind ---> mind
# when ---> when
# you ---> you
# hear ---> hear
# it ---> it
# you ---> you
# know ---> know
# what ---> what
# sucks ---> suck
# being ---> be
# the ---> the
# person ---> person
# who ---> who
# always ---> alway
# cares ---> care
# more ---> more
# Never ---> never
# regret ---> regret
# something ---> someth
# that ---> that
# once ---> onc
# made ---> made
# you ---> you
# happy ---> happi
# I ---> i
# want ---> want
# to ---> to
# just ---> just
# forget ---> forget
# but ---> but
# I ---> i
# ca ---> ca
# Be ---> be
# strong ---> strong
# and ---> and
# smile ---> smile
# at ---> at
# life ---> life
# even ---> even
# though ---> though
# it ---> it
# hurts ---> hurt
# sometimes ---> sometim
# I ---> i
# always ---> alway
# say ---> say
# i ---> i
# done ---> done
# with ---> with
# you ---> you
# but ---> but
# I ---> i
# never ---> never
# am ---> am
# Stop ---> stop
# wishing ---> wish
# Start ---> start
# working ---> work
# Do ---> do
# blame ---> blame
# people ---> peopl
# for ---> for
# disappointing ---> disappoint
# you ---> you
# Blame ---> blame
# yourself ---> yourself
# for ---> for
# expecting ---> expect
# too ---> too
# much ---> much
# That ---> that
# awkward ---> awkward
# moment ---> moment
# when ---> when
# you ---> you
# yelling ---> yell
# at ---> at
# someone ---> someon
# and ---> and
# you ---> you
# mess ---> mess
# up ---> up
# a ---> a
# word ---> word
# Mistakes ---> mistak
# are ---> are
# proof ---> proof
# that ---> that
# you ---> you
# trying ---> tri
# Is ---> is
# it ---> it
# just ---> just
# me ---> me
# or ---> or
# was ---> wa
# this ---> thi
# year ---> year
# like ---> like
# really ---> realli
# fucking ---> fuck
# overwhelming ---> overwhelm
# like ---> like
# everything ---> everyth
# that ---> that
# happened ---> happen
# to ---> to
# you ---> you
# this ---> thi
# year ---> year
# has ---> ha
# shaped ---> shape
# you ---> you
# into ---> into
# a ---> a
# completely ---> complet
# different ---> differ
# person ---> person
# that ---> that
# you ---> you
# were ---> were
# at ---> at
# the ---> the
# beginning ---> begin
# of ---> of
# this ---> thi
# year ---> year
# Never ---> never
# underestimate ---> underestim
# the ---> the
# power ---> power
# of ---> of
# your ---> your
# words ---> word
# Use ---> use
# them ---> them
# to ---> to
# lift ---> lift
# others ---> other
# up ---> up
# not ---> not
# break ---> break
# them ---> them
# down ---> down
# I ---> i
# get ---> get
# jealous ---> jealou
# over ---> over
# the ---> the
# stupidest ---> stupidest
# things ---> thing
# sometimes ---> sometim
# Be ---> be
# strong ---> strong
# and ---> and
# move ---> move
# on ---> on
# It ---> it
# time ---> time
# The ---> the
# less ---> less
# you ---> you
# care ---> care
# the ---> the
# happier ---> happier
# you ---> you
# be ---> be
# Allow ---> allow
# yourself ---> yourself
# to ---> to
# be ---> be
# a ---> a
# beginner ---> beginn
# No ---> no
# one ---> one
# starts ---> start
# off ---> off
# being ---> be
# excellent ---> excel
# Be ---> be
# thankful ---> thank
# for ---> for
# what ---> what
# you ---> you
# have ---> have
# You ---> you
# have ---> have
# no ---> no
# idea ---> idea
# how ---> how
# many ---> mani
# people ---> peopl
# would ---> would
# love ---> love
# to ---> to
# have ---> have
# what ---> what
# you ---> you
# got ---> got
# Some ---> some
# people ---> peopl
# are ---> are
# actually ---> actual
# anti ---> anti
# social ---> social
# they ---> they
# just ---> just
# very ---> veri
# selective ---> select
# when ---> when
# it ---> it
# comes ---> come
# to ---> to
# the ---> the
# people ---> peopl
# they ---> they
# associate ---> associ
# with ---> with
# Be ---> be
# strong ---> strong
# and ---> and
# smile ---> smile
# at ---> at
# life ---> life
# even ---> even
# though ---> though
# it ---> it
# hurts ---> hurt
# sometimes ---> sometim
# Trust ---> trust
# is ---> is
# like ---> like
# an ---> an
# eraser ---> eras
# It ---> it
# gets ---> get
# smaller ---> smaller
# with ---> with
# every ---> everi
# mistake ---> mistak
# you ---> you
# make ---> make
# Current ---> current
# mood ---> mood
# do ---> do
# talk ---> talk
# to ---> to
# me ---> me
# Do ---> do
# not ---> not
# pray ---> pray
# for ---> for
# an ---> an
# easy ---> easi
# life ---> life
# pray ---> pray
# for ---> for
# the ---> the
# strength ---> strength
# to ---> to
# endure ---> endur
# a ---> a
# difficult ---> difficult
# one ---> one
# I ---> i
# really ---> realli
# hate ---> hate
# when ---> when
# friends ---> friend
# change ---> chang
# just ---> just
# because ---> becaus
# they ---> they
# meet ---> meet
# new ---> new
# people ---> peopl
# Everything ---> everyth
# happens ---> happen
# for ---> for
# a ---> a
# reason ---> reason
# Once ---> onc
# you ---> you
# been ---> been
# hurt ---> hurt
# you ---> you
# so ---> so
# scared ---> scare
# to ---> to
# get ---> get
# attached ---> attach
# again ---> again
# You ---> you
# have ---> have
# this ---> thi
# fear ---> fear
# that ---> that
# everyone ---> everyon
# you ---> you
# like ---> like
# is ---> is
# gon ---> gon
# na ---> na
# break ---> break
# your ---> your
# heart ---> heart
# No ---> no
# expectations ---> expect
# no ---> no
# disappointments ---> disappoint
# I ---> i
# ca ---> ca
# lie ---> lie
# i ---> i
# miss ---> miss
# you ---> you
# so ---> so
# much ---> much
# remind ---> remind
# them ---> them
# what ---> what
# they ---> they
# lost ---> lost
# I ---> i
# not ---> not
# afraid ---> afraid
# to ---> to
# try ---> tri
# again ---> again
# I ---> i
# just ---> just
# afraid ---> afraid
# of ---> of
# getting ---> get
# hurt ---> hurt
# for ---> for
# the ---> the
# same ---> same
# reason ---> reason
# person ---> person
# how ---> how
# are ---> are
# you ---> you
# me ---> me
# I ---> i
# have ---> have
# literally ---> liter
# no ---> no
# idea ---> idea
# That ---> that
# moment ---> moment
# when ---> when
# you ---> you
# and ---> and
# your ---> your
# best ---> best
# friend ---> friend
# look ---> look
# at ---> at
# each ---> each
# other ---> other
# and ---> and
# know ---> know
# what ---> what
# you ---> you
# both ---> both
# are ---> are
# thinking ---> think
# and ---> and
# laugh ---> laugh
# It ---> it
# not ---> not
# hard ---> hard
# to ---> to
# find ---> find
# someone ---> someon
# who ---> who
# tells ---> tell
# you ---> you
# they ---> they
# love ---> love
# you ---> you
# it ---> it
# hard ---> hard
# to ---> to
# find ---> find
# someone ---> someon
# who ---> who
# actually ---> actual
# means ---> mean
# it ---> it
# Do ---> do
# waste ---> wast
# your ---> your
# time ---> time
# with ---> with
# people ---> peopl
# who ---> who
# do ---> do
# appreciate ---> appreci
# you ---> you
# Being ---> be
# single ---> singl
# is ---> is
# not ---> not
# a ---> a
# status ---> statu
# It ---> it
# a ---> a
# time ---> time
# in ---> in
# your ---> your
# life ---> life
# when ---> when
# you ---> you
# get ---> get
# to ---> to
# be ---> be
# happy ---> happi
# and ---> and
# enjoy ---> enjoy
# yourself ---> yourself
# without ---> without
# depending ---> depend
# on ---> on
# someone ---> someon
# else ---> els
# Do ---> do
# put ---> put
# your ---> your
# happiness ---> happi
# in ---> in
# the ---> the
# hands ---> hand
# of ---> of
# someone ---> someon
# else ---> els
# If ---> if
# you ---> you
# really ---> realli
# want ---> want
# to ---> to
# be ---> be
# happy ---> happi
# you ---> you
# have ---> have
# to ---> to
# find ---> find
# this ---> thi
# happiness ---> happi
# within ---> within
# yourself ---> yourself
# Stop ---> stop
# overthinking ---> overthink
# Relax ---> relax
# and ---> and
# let ---> let
# it ---> it
# go ---> go
# things ---> thing
# change ---> chang
# people ---> peopl
# change ---> chang
# feelings ---> feel
# change ---> chang
# too ---> too
# Never ---> never
# let ---> let
# someone ---> someon
# take ---> take
# advantage ---> advantag
# of ---> of
# you ---> you
# Stand ---> stand
# up ---> up
# for ---> for
# yourself ---> yourself
# you ---> you
# deserve ---> deserv
# the ---> the
# best ---> best
# It ---> it
# better ---> better
# to ---> to
# be ---> be
# slapped ---> slap
# by ---> by
# the ---> the
# truth ---> truth
# than ---> than
# kissed ---> kiss
# with ---> with
# a ---> a
# lie ---> lie
# I ---> i
# want ---> want
# those ---> those
# sweet ---> sweet
# days ---> day
# back ---> back
# again ---> again
# To ---> to
# be ---> be
# successful ---> success
# you ---> you
# must ---> must
# accept ---> accept
# all ---> all
# challenges ---> challeng
# that ---> that
# come ---> come
# your ---> your
# way ---> way
# You ---> you
# ca ---> ca
# just ---> just
# accept ---> accept
# the ---> the
# ones ---> one
# you ---> you
# like ---> like
# My ---> my
# favorite ---> favorit
# texts ---> text
# are ---> are
# the ---> the
# ones ---> one
# where ---> where
# you ---> you
# and ---> and
# it ---> it
# still ---> still
# puts ---> put
# a ---> a
# smile ---> smile
# on ---> on
# your ---> your
# face ---> face
# like ---> like
# it ---> it
# the ---> the
# first ---> first
# time ---> time
# you ---> you
# read ---> read
# it ---> it
# stress ---> stress
# is ---> is
# caused ---> caus
# by ---> by
# caring ---> care
# You ---> you
# will ---> will
# become ---> becom
# an ---> an
# adult ---> adult
# You ---> you
# will ---> will
# figure ---> figur
# out ---> out
# your ---> your
# career ---> career
# You ---> you
# will ---> will
# find ---> find
# someone ---> someon
# who ---> who
# loves ---> love
# you ---> you
# You ---> you
# have ---> have
# a ---> a
# whole ---> whole
# life ---> life
# it ---> it
# takes ---> take
# time ---> time
# My ---> my
# heart ---> heart
# drops ---> drop
# when ---> when
# I ---> i
# think ---> think
# about ---> about
# you ---> you
# being ---> be
# with ---> with
# someone ---> someon
# else ---> els
# I ---> i
# need ---> need
# to ---> to
# stop ---> stop
# being ---> be
# so ---> so
# emotional ---> emot
# about ---> about
# everything ---> everyth
# Do ---> do
# let ---> let
# your ---> your
# emotions ---> emot
# make ---> make
# your ---> your
# decisions ---> decis
# You ---> you
# are ---> are
# the ---> the
# one ---> one
# I ---> i
# picture ---> pictur
# myself ---> myself
# with ---> with
# in ---> in
# the ---> the
# future ---> futur
# Love ---> love
# when ---> when
# you ---> you
# ready ---> readi
# not ---> not
# when ---> when
# you ---> you
# lonely ---> lone
# I ---> i
# need ---> need
# to ---> to
# be ---> be
# strong ---> strong
# for ---> for
# myself ---> myself
# Be ---> be
# strong ---> strong
# now ---> now
# Things ---> thing
# will ---> will
# get ---> get
# better ---> better
# I ---> i
# hate ---> hate
# friendships ---> friendship
# that ---> that
# end ---> end
# for ---> for
# no ---> no
# damn ---> damn
# reason ---> reason
# Do ---> do
# give ---> give
# up ---> up
# great ---> great
# things ---> thing
# take ---> take
# time ---> time
# You ---> you
# always ---> alway
# on ---> on
# my ---> my
# mind ---> mind
# Never ---> never
# judge ---> judg
# a ---> a
# situation ---> situat
# that ---> that
# you ---> you
# never ---> never
# been ---> been
# in ---> in
# Hard ---> hard
# times ---> time
# will ---> will
# always ---> alway
# reveal ---> reveal
# true ---> true
# friends ---> friend
# School ---> school
# does ---> doe
# even ---> even
# test ---> test
# your ---> your
# intelligence ---> intellig
# it ---> it
# tests ---> test
# your ---> your
# memory ---> memori
# From ---> from
# All ---> all
# The ---> the
# Toys ---> toy
# In ---> in
# The ---> the
# World ---> world
# People ---> peopl
# Choose ---> choos
# Feelings ---> feel
# To ---> to
# Play ---> play
# With ---> with
# Those ---> those
# who ---> who
# are ---> are
# heartless ---> heartless
# once ---> onc
# cared ---> care
# too ---> too
# much ---> much
# Tired ---> tire
# of ---> of
# everything ---> everyth
# Do ---> do
# rush ---> rush
# anything ---> anyth
# When ---> when
# the ---> the
# time ---> time
# is ---> is
# right ---> right
# it ---> it
# will ---> will
# happen ---> happen
# Dear ---> dear
# Feelings ---> feel
# I ---> i
# need ---> need
# you ---> you
# to ---> to
# move ---> move
# on ---> on
# Sometimes ---> sometim
# I ---> i
# just ---> just
# love ---> love
# you ---> you
# too ---> too
# much ---> much
# that ---> that
# it ---> it
# hurts ---> hurt
# A ---> a
# true ---> true
# friend ---> friend
# who ---> who
# understands ---> understand
# your ---> your
# troubles ---> troubl
# is ---> is
# more ---> more
# valuable ---> valuabl
# than ---> than
# a ---> a
# hundred ---> hundr
# friends ---> friend
# who ---> who
# only ---> onli
# show ---> show
# up ---> up
# for ---> for
# your ---> your
# smiles ---> smile
# Happiness ---> happi
# comes ---> come
# when ---> when
# you ---> you
# stop ---> stop
# complaining ---> complain
# about ---> about
# your ---> your
# problems ---> problem
# and ---> and
# you ---> you
# start ---> start
# being ---> be
# grateful ---> grate
# for ---> for
# the ---> the
# problems ---> problem
# you ---> you
# do ---> do
# have ---> have
# When ---> when
# drake ---> drake
# said ---> said
# We ---> we
# live ---> live
# in ---> in
# a ---> a
# generation ---> gener
# of ---> of
# not ---> not
# being ---> be
# in ---> in
# love ---> love
# not ---> not
# being ---> be
# together ---> togeth
# but ---> but
# we ---> we
# sure ---> sure
# make ---> make
# it ---> it
# feel ---> feel
# like ---> like
# we ---> we
# together ---> togeth
# because ---> becaus
# we ---> we
# scared ---> scare
# to ---> to
# see ---> see
# each ---> each
# other ---> other
# with ---> with
# somebody ---> somebodi
# else ---> els
# I ---> i
# felt ---> felt
# that ---> that
# shit ---> shit
# deep ---> deep
# in ---> in
# my ---> my
# soul ---> soul
# I ---> i
# do ---> do
# trust ---> trust
# words ---> word
# I ---> i
# trust ---> trust
# actions ---> action
# Losing ---> lose
# some ---> some
# people ---> peopl
# is ---> is
# a ---> a
# gain ---> gain
# Hey ---> hey
# i ---> i
# miss ---> miss
# you ---> you
# Sometimes ---> sometim
# you ---> you
# ca ---> ca
# explain ---> explain
# what ---> what
# you ---> you
# feel ---> feel
# for ---> for
# a ---> a
# person ---> person
# I ---> i
# want ---> want
# to ---> to
# go ---> go
# to ---> to
# sleep ---> sleep
# at ---> at
# night ---> night
# wake ---> wake
# up ---> up
# every ---> everi
# day ---> day
# and ---> and
# breathe ---> breath
# knowing ---> know
# you ---> you
# are ---> are
# truly ---> truli
# mine ---> mine
# I ---> i
# wish ---> wish
# you ---> you
# could ---> could
# hear ---> hear
# all ---> all
# the ---> the
# words ---> word
# I ---> i
# too ---> too
# afraid ---> afraid
# to ---> to
# say ---> say
# Sometimes ---> sometim
# you ---> you
# expect ---> expect
# more ---> more
# from ---> from
# someone ---> someon
# because ---> becaus
# you ---> you
# would ---> would
# do ---> do
# that ---> that
# much ---> much
# for ---> for
# them ---> them
# I ---> i
# notice ---> notic
# everything ---> everyth
# but ---> but
# i ---> i
# keep ---> keep
# my ---> my
# mouth ---> mouth
# shut ---> shut
# i ---> i
# wish ---> wish
# i ---> i
# could ---> could
# stop ---> stop
# overthinking ---> overthink
# shit ---> shit
# I ---> i
# an ---> an
# expert ---> expert
# in ---> in
# overthinking ---> overthink
# If ---> if
# you ---> you
# truly ---> truli
# love ---> love
# someone ---> someon
# being ---> be
# faithful ---> faith
# is ---> is
# easy ---> easi
# Do ---> do
# stress ---> stress
# Do ---> do
# your ---> your
# best ---> best
# Forget ---> forget
# the ---> the
# rest ---> rest
# Everything ---> everyth
# gets ---> get
# better ---> better
# with ---> with
# time ---> time
# One ---> one
# day ---> day
# I ---> i
# going ---> go
# to ---> to
# prove ---> prove
# everyone ---> everyon
# wrong ---> wrong
# It ---> it
# so ---> so
# hard ---> hard
# to ---> to
# forget ---> forget
# someone ---> someon
# that ---> that
# you ---> you
# shared ---> share
# so ---> so
# many ---> mani
# memories ---> memori
# with ---> with
# You ---> you
# be ---> be
# okay ---> okay
# Not ---> not
# now ---> now
# but ---> but
# soon ---> soon
# I ---> i
# wish ---> wish
# I ---> i
# could ---> could
# see ---> see
# you ---> you
# Literally ---> liter
# right ---> right
# now ---> now
# at ---> at
# this ---> thi
# very ---> veri
# second ---> second
# I ---> i
# want ---> want
# to ---> to
# be ---> be
# with ---> with
# you ---> you
# Beautiful ---> beauti
# faces ---> face
# are ---> are
# everywhere ---> everywher
# but ---> but
# beautiful ---> beauti
# minds ---> mind
# are ---> are
# hard ---> hard
# to ---> to
# find ---> find
# Having ---> have
# anxiety ---> anxieti
# is ---> is
# the ---> the
# most ---> most
# silently ---> silent
# painful ---> pain
# experience ---> experi
# It ---> it
# makes ---> make
# no ---> no
# sense ---> sens
# and ---> and
# you ---> you
# sit ---> sit
# there ---> there
# alone ---> alon
# and ---> and
# suffer ---> suffer
# for ---> for
# an ---> an
# unknown ---> unknown
# reason ---> reason
# We ---> we
# used ---> use
# to ---> to
# talk ---> talk
# everyday ---> everyday
# and ---> and
# now ---> now
# its ---> it
# like ---> like
# we ---> we
# dont ---> dont
# even ---> even
# know ---> know
# each ---> each
# other ---> other
# Surround ---> surround
# yourself ---> yourself
# with ---> with
# positive ---> posit
# people ---> peopl
# who ---> who
# will ---> will
# support ---> support
# you ---> you
# when ---> when
# it ---> it
# rains ---> rain
# not ---> not
# just ---> just
# when ---> when
# it ---> it
# shines ---> shine
# A ---> a
# good ---> good
# relationship ---> relationship
# is ---> is
# worth ---> worth
# the ---> the
# wait ---> wait
# When ---> when
# you ---> you
# are ---> are
# right ---> right
# no ---> no
# one ---> one
# remembers ---> rememb
# When ---> when
# you ---> you
# wrong ---> wrong
# no ---> no
# one ---> one
# forgets ---> forget
# It ---> it
# your ---> your
# life ---> life
# Do ---> do
# let ---> let
# anyone ---> anyon
# make ---> make
# you ---> you
# feel ---> feel
# guilty ---> guilti
# for ---> for
# living ---> live
# it ---> it
# your ---> your
# way ---> way
# I ---> i
# wanted ---> want
# to ---> to
# text ---> text
# you ---> you
# but ---> but
# I ---> i
# do ---> do
# want ---> want
# to ---> to
# annoy ---> annoy
# you ---> you
# I ---> i
# just ---> just
# want ---> want
# to ---> to
# forget ---> forget
# about ---> about
# everything ---> everyth
# that ---> that
# hurts ---> hurt
# Relationships ---> relationship
# fail ---> fail
# because ---> becaus
# girls ---> girl
# love ---> love
# too ---> too
# much ---> much
# and ---> and
# the ---> the
# boys ---> boy
# love ---> love
# too ---> too
# many ---> mani
# I ---> i
# miss ---> miss
# you ---> you
# and ---> and
# I ---> i
# wish ---> wish
# you ---> you
# were ---> were
# here ---> here
# Do ---> do
# depend ---> depend
# too ---> too
# much ---> much
# on ---> on
# anyone ---> anyon
# in ---> in
# this ---> thi
# world ---> world
# because ---> becaus
# even ---> even
# your ---> your
# own ---> own
# shadow ---> shadow
# leaves ---> leav
# you ---> you
# when ---> when
# you ---> you
# are ---> are
# in ---> in
# darkness ---> dark
# Dream ---> dream
# big ---> big
# work ---> work
# hard ---> hard
# stay ---> stay
# focused ---> focus
# and ---> and
# surround ---> surround
# yourself ---> yourself
# with ---> with
# good ---> good
# people ---> peopl
# I ---> i
# love ---> love
# getting ---> get
# good ---> good
# night ---> night
# text ---> text
# messages ---> messag
# because ---> becaus
# to ---> to
# me ---> me
# it ---> it
# means ---> mean
# I ---> i
# was ---> wa
# the ---> the
# last ---> last
# thing ---> thing
# on ---> on
# your ---> your
# mind ---> mind
# Every ---> everi
# time ---> time
# I ---> i
# see ---> see
# you ---> you
# I ---> i
# fall ---> fall
# in ---> in
# love ---> love
# all ---> all
# over ---> over
# again ---> again
# If ---> if
# you ---> you
# do ---> do
# fight ---> fight
# for ---> for
# what ---> what
# you ---> you
# want ---> want
# do ---> do
# cry ---> cri
# for ---> for
# what ---> what
# you ---> you
# lost ---> lost
# see ---> see
# people ---> peopl
# for ---> for
# who ---> who
# they ---> they
# are ---> are
# not ---> not
# who ---> who
# they ---> they
# pretend ---> pretend
# to ---> to
# be ---> be
# When ---> when
# you ---> you
# think ---> think
# you ---> you
# not ---> not
# happy ---> happi
# with ---> with
# your ---> your
# life ---> life
# always ---> alway
# think ---> think
# that ---> that
# someone ---> someon
# is ---> is
# happy ---> happi
# simply ---> simpli
# because ---> becaus
# you ---> you
# exist ---> exist
# You ---> you
# guys ---> guy
# talk ---> talk
# Nah ---> nah
# we ---> we
# just ---> just
# argue ---> argu
# Sometimes ---> sometim
# you ---> you
# just ---> just
# need ---> need
# to ---> to
# distance ---> distanc
# yourself ---> yourself
# from ---> from
# people ---> peopl
# Just ---> just
# because ---> becaus
# it ---> it
# not ---> not
# happening ---> happen
# right ---> right
# now ---> now
# does ---> doe
# mean ---> mean
# it ---> it
# never ---> never
# will ---> will
# Haha ---> haha
# is ---> is
# the ---> the
# best ---> best
# way ---> way
# to ---> to
# hide ---> hide
# your ---> your
# pain ---> pain
# I ---> i
# do ---> do
# hate ---> hate
# you ---> you
# I ---> i
# just ---> just
# disappointed ---> disappoint
# you ---> you
# turned ---> turn
# into ---> into
# everything ---> everyth
# you ---> you
# said ---> said
# you ---> you
# never ---> never
# be ---> be
# No ---> no
# matter ---> matter
# how ---> how
# busy ---> busi
# a ---> a
# person ---> person
# day ---> day
# may ---> may
# be ---> be
# If ---> if
# they ---> they
# really ---> realli
# care ---> care
# they ---> they
# always ---> alway
# find ---> find
# time ---> time
# for ---> for
# you ---> you
# Sometimes ---> sometim
# the ---> the
# perfect ---> perfect
# person ---> person
# for ---> for
# you ---> you
# is ---> is
# who ---> who
# you ---> you
# least ---> least
# expected ---> expect
# it ---> it
# to ---> to
# be ---> be
# Sometimes ---> sometim
# words ---> word
# are ---> are
# not ---> not
# enough ---> enough
# Do ---> do
# force ---> forc
# someone ---> someon
# to ---> to
# make ---> make
# time ---> time
# for ---> for
# you ---> you
# if ---> if
# they ---> they
# really ---> realli
# want ---> want
# to ---> to
# they ---> they
# will ---> will
# A ---> a
# real ---> real
# boyfriend ---> boyfriend
# calls ---> call
# you ---> you
# for ---> for
# nothing ---> noth
# texts ---> text
# you ---> you
# all ---> all
# the ---> the
# time ---> time
# wants ---> want
# to ---> to
# see ---> see
# you ---> you
# gets ---> get
# jealous ---> jealou
# is ---> is
# overprotective ---> overprotect
# Patience ---> patienc
# is ---> is
# the ---> the
# key ---> key
# because ---> becaus
# when ---> when
# the ---> the
# right ---> right
# time ---> time
# comes ---> come
# it ---> it
# will ---> will
# be ---> be
# very ---> veri
# beautiful ---> beauti
# and ---> and
# totally ---> total
# worth ---> worth
# the ---> the
# wait ---> wait
# Be ---> be
# real ---> real
# be ---> be
# yourself ---> yourself
# be ---> be
# unique ---> uniqu
# be ---> be
# true ---> true
# be ---> be
# honest ---> honest
# be ---> be
# humble ---> humbl
# be ---> be
# happy ---> happi
# Enjoy ---> enjoy
# life ---> life
# the ---> the
# way ---> way
# it ---> it
# is ---> is
# Once ---> onc
# you ---> you
# been ---> been
# hurt ---> hurt
# you ---> you
# so ---> so
# scared ---> scare
# to ---> to
# get ---> get
# attached ---> attach
# again ---> again
# You ---> you
# have ---> have
# this ---> thi
# fear ---> fear
# that ---> that
# everyone ---> everyon
# you ---> you
# like ---> like
# is ---> is
# gon ---> gon
# na ---> na
# break ---> break
# your ---> your
# heart ---> heart
# You ---> you
# are ---> are
# responsible ---> respons
# for ---> for
# your ---> your
# own ---> own
# happiness ---> happi
# If ---> if
# you ---> you
# expect ---> expect
# others ---> other
# to ---> to
# make ---> make
# you ---> you
# happy ---> happi
# you ---> you
# will ---> will
# always ---> alway
# be ---> be
# disappointed ---> disappoint
# I ---> i
# a ---> a
# little ---> littl
# on ---> on
# the ---> the
# jealous ---> jealou
# side ---> side
# but ---> but
# it ---> it
# only ---> onli
# because ---> becaus
# I ---> i
# do ---> do
# want ---> want
# anyone ---> anyon
# else ---> els
# to ---> to
# get ---> get
# a ---> a
# chance ---> chanc
# to ---> to
# have ---> have
# you ---> you
# I ---> i
# wish ---> wish
# I ---> i
# was ---> wa
# a ---> a
# little ---> littl
# kid ---> kid
# again ---> again
# Do ---> do
# give ---> give
# up ---> up
# Great ---> great
# things ---> thing
# take ---> take
# time ---> time
# Do ---> do
# trust ---> trust
# too ---> too
# much ---> much
# Do ---> do
# love ---> love
# too ---> too
# much ---> much
# Do ---> do
# hope ---> hope
# too ---> too
# much ---> much
# because ---> becaus
# that ---> that
# too ---> too
# much ---> much
# can ---> can
# hurt ---> hurt
# you ---> you
# so ---> so
# much ---> much
# I ---> i
# love ---> love
# my ---> my
# mom ---> mom
# more ---> more
# than ---> than
# anyone ---> anyon
# else ---> els
# in ---> in
# this ---> thi
# world ---> world
# We ---> we
# can ---> can
# not ---> not
# learn ---> learn
# without ---> without
# experiencing ---> experienc
# pain ---> pain
# She ---> she
# says ---> say
# she ---> she
# does ---> doe
# care ---> care
# but ---> but
# her ---> her
# eyes ---> eye
# tell ---> tell
# a ---> a
# different ---> differ
# story ---> stori
# When ---> when
# someone ---> someon
# treats ---> treat
# you ---> you
# like ---> like
# an ---> an
# option ---> option
# help ---> help
# them ---> them
# narrow ---> narrow
# their ---> their
# choices ---> choic
# by ---> by
# removing ---> remov
# yourself ---> yourself
# from ---> from
# the ---> the
# equation ---> equat
# It ---> it
# that ---> that
# simple ---> simpl
# No ---> no
# road ---> road
# is ---> is
# long ---> long
# with ---> with
# good ---> good
# company ---> compani
# Do ---> do
# look ---> look
# back ---> back
# and ---> and
# wonder ---> wonder
# why ---> whi
# things ---> thing
# went ---> went
# wrong ---> wrong
# Do ---> do
# regret ---> regret
# not ---> not
# doing ---> do
# more ---> more
# It ---> it
# happened ---> happen
# for ---> for
# a ---> a
# reason ---> reason
# Your ---> your
# better ---> better
# days ---> day
# are ---> are
# ahead ---> ahead
# of ---> of
# you ---> you
# Eventually ---> eventu
# all ---> all
# things ---> thing
# fall ---> fall
# into ---> into
# place ---> place
# Until ---> until
# then ---> then
# laugh ---> laugh
# at ---> at
# the ---> the
# confusion ---> confus
# live ---> live
# for ---> for
# the ---> the
# moments ---> moment
# and ---> and
# know ---> know
# everything ---> everyth
# happens ---> happen
# for ---> for
# a ---> a
# reason ---> reason
# I ---> i
# need ---> need
# to ---> to
# stop ---> stop
# overthinking ---> overthink
# We ---> we
# all ---> all
# have ---> have
# that ---> that
# one ---> one
# person ---> person
# that ---> that
# we ---> we
# always ---> alway
# have ---> have
# feelings ---> feel
# for ---> for
# no ---> no
# matter ---> matter
# what ---> what
# Just ---> just
# one ---> one
# look ---> look
# and ---> and
# it ---> it
# takes ---> take
# you ---> you
# right ---> right
# back ---> back
# to ---> to
# those ---> those
# memories ---> memori
# Sometimes ---> sometim
# someone ---> someon
# says ---> say
# something ---> someth
# really ---> realli
# small ---> small
# and ---> and
# it ---> it
# just ---> just
# fits ---> fit
# right ---> right
# into ---> into
# this ---> thi
# empty ---> empti
# place ---> place
# in ---> in
# your ---> your
# heart ---> heart
# Be ---> be
# with ---> with
# someone ---> someon
# who ---> who
# brings ---> bring
# out ---> out
# the ---> the
# best ---> best
# in ---> in
# you ---> you
# not ---> not
# the ---> the
# stress ---> stress
# in ---> in
# you ---> you
# We ---> we
# fall ---> fall
# in ---> in
# love ---> love
# by ---> by
# chance ---> chanc
# we ---> we
# stay ---> stay
# in ---> in
# love ---> love
# by ---> by
# choice ---> choic
# Sometimes ---> sometim
# it ---> it
# the ---> the
# smallest ---> smallest
# decisions ---> decis
# that ---> that
# can ---> can
# change ---> chang
# your ---> your
# life ---> life
# forever ---> forev
# If ---> if
# I ---> i
# forgive ---> forgiv
# you ---> you
# once ---> onc
# do ---> do
# mess ---> mess
# up ---> up
# twice ---> twice
# Stand ---> stand
# up ---> up
# for ---> for
# what ---> what
# you ---> you
# believe ---> believ
# in ---> in
# even ---> even
# if ---> if
# you ---> you
# standing ---> stand
# alone ---> alon
# If ---> if
# you ---> you
# are ---> are
# buying ---> buy
# test ---> test
# them ---> them
# with ---> with
# Bohemian ---> bohemian
# Rhapsody ---> rhapsodi
# It ---> it
# has ---> ha
# the ---> the
# complete ---> complet
# set ---> set
# of ---> of
# highs ---> high
# and ---> and
# lows ---> low
# in ---> in
# instruments ---> instrument
# and ---> and
# vocals ---> vocal
# being ---> be
# a ---> a
# girl ---> girl
# is ---> is
# really ---> realli
# fucking ---> fuck
# expensive ---> expens
# Sometimes ---> sometim
# I ---> i
# pretend ---> pretend
# that ---> that
# I ---> i
# do ---> do
# care ---> care
# But ---> but
# really ---> realli
# I ---> i
# care ---> care
# more ---> more
# than ---> than
# anyone ---> anyon
# else ---> els
# ever ---> ever
# will ---> will
# I ---> i
# want ---> want
# you ---> you
# today ---> today
# tomorrow ---> tomorrow
# next ---> next
# week ---> week
# and ---> and
# for ---> for
# the ---> the
# rest ---> rest
# of ---> of
# my ---> my
# life ---> life
# Just ---> just
# because ---> becaus
# we ---> we
# not ---> not
# talking ---> talk
# does ---> doe
# mean ---> mean
# I ---> i
# do ---> do
# miss ---> miss
# you ---> you
# just ---> just
# because ---> becaus
# her ---> her
# eyes ---> eye
# do ---> do
# tear ---> tear
# up ---> up
# does ---> doe
# mean ---> mean
# her ---> her
# heart ---> heart
# does ---> doe
# cry ---> cri
# and ---> and
# just ---> just
# because ---> becaus
# she ---> she
# comes ---> come
# off ---> off
# strong ---> strong
# does ---> doe
# mean ---> mean
# nothing ---> noth
# is ---> is
# wrong ---> wrong
# No ---> no
# matter ---> matter
# how ---> how
# busy ---> busi
# a ---> a
# person ---> person
# is ---> is
# if ---> if
# they ---> they
# care ---> care
# they ---> they
# will ---> will
# always ---> alway
# find ---> find
# time ---> time
# for ---> for
# you ---> you
# Music ---> music
# makes ---> make
# life ---> life
# so ---> so
# much ---> much
# better ---> better
# Never ---> never
# waste ---> wast
# your ---> your
# feelings ---> feel
# on ---> on
# people ---> peopl
# who ---> who
# do ---> do
# value ---> valu
# them ---> them
# Every ---> everi
# time ---> time
# my ---> my
# phone ---> phone
# vibrates ---> vibrat
# I ---> i
# hope ---> hope
# it ---> it
# you ---> you
# Be ---> be
# strong ---> strong
# now ---> now
# Things ---> thing
# will ---> will
# get ---> get
# better ---> better
# Sometimes ---> sometim
# creating ---> creat
# a ---> a
# little ---> littl
# distance ---> distanc
# will ---> will
# help ---> help
# people ---> peopl
# recognize ---> recogn
# how ---> how
# much ---> much
# you ---> you
# actually ---> actual
# mean ---> mean
# to ---> to
# them ---> them
# one ---> one
# day ---> day
# it ---> it
# wo ---> wo
# hurt ---> hurt
# anymore ---> anymor
# True ---> true
# love ---> love
# has ---> ha
# no ---> no
# happy ---> happi
# ending ---> end
# because ---> becaus
# it ---> it
# never ---> never
# ends ---> end
# Do ---> do
# let ---> let
# your ---> your
# emotions ---> emot
# make ---> make
# your ---> your
# decisions ---> decis
# If ---> if
# you ---> you
# lucky ---> lucki
# enough ---> enough
# to ---> to
# get ---> get
# a ---> a
# second ---> second
# chance ---> chanc
# at ---> at
# something ---> someth
# do ---> do
# waste ---> wast
# it ---> it
# Everything ---> everyth
# is ---> is
# going ---> go
# to ---> to
# be ---> be
# alright ---> alright
# maybe ---> mayb
# not ---> not
# today ---> today
# but ---> but
# eventually ---> eventu
# been ---> been
# realizing ---> realiz
# a ---> a
# lot ---> lot
# lately ---> late
# Sometimes ---> sometim
# you ---> you
# just ---> just
# need ---> need
# to ---> to
# distance ---> distanc
# yourself ---> yourself
# from ---> from
# people ---> peopl
# If ---> if
# they ---> they
# care ---> care
# they ---> they
# notice ---> notic
# If ---> if
# they ---> they
# do ---> do
# you ---> you
# know ---> know
# where ---> where
# you ---> you
# stand ---> stand
# I ---> i
# just ---> just
# want ---> want
# real ---> real
# happiness ---> happi
# in ---> in
# life ---> life
# The ---> the
# worst ---> worst
# thing ---> thing
# you ---> you
# can ---> can
# do ---> do
# to ---> to
# a ---> a
# girl ---> girl
# is ---> is
# compare ---> compar
# her ---> her
# to ---> to
# another ---> anoth
# girl ---> girl
# I ---> i
# just ---> just
# thankful ---> thank
# for ---> for
# the ---> the
# people ---> peopl
# that ---> that
# never ---> never
# left ---> left
# me ---> me
# It ---> it
# so ---> so
# beautiful ---> beauti
# how ---> how
# we ---> we
# find ---> find
# people ---> peopl
# who ---> who
# can ---> can
# make ---> make
# us ---> us
# feel ---> feel
# so ---> so
# happy ---> happi
# even ---> even
# at ---> at
# the ---> the
# times ---> time
# when ---> when
# we ---> we
# do ---> do
# believe ---> believ
# in ---> in
# happiness ---> happi
# at ---> at
# all ---> all
# Sometimes ---> sometim
# I ---> i
# wan ---> wan
# na ---> na
# disappear ---> disappear
# and ---> and
# let ---> let
# the ---> the
# world ---> world
# forget ---> forget
# that ---> that
# I ---> i
# existed ---> exist
# Sometimes ---> sometim
# all ---> all
# you ---> you
# need ---> need
# is ---> is
# someone ---> someon
# who ---> who
# can ---> can
# make ---> make
# you ---> you
# smile ---> smile
# May ---> may
# the ---> the
# tears ---> tear
# I ---> i
# cried ---> cri
# in ---> in
# be ---> be
# the ---> the
# nourishment ---> nourish
# to ---> to
# the ---> the
# soil ---> soil
# of ---> of
# Cuddling ---> cuddl
# with ---> with
# you ---> you
# would ---> would
# be ---> be
# so ---> so
# perfect ---> perfect
# right ---> right
# now ---> now
# Wrong ---> wrong
# is ---> is
# wrong ---> wrong
# even ---> even
# if ---> if
# everyone ---> everyon
# is ---> is
# doing ---> do
# it ---> it
# Right ---> right
# is ---> is
# right ---> right
# even ---> even
# if ---> if
# no ---> no
# one ---> one
# is ---> is
# doing ---> do
# it ---> it
# Beautiful ---> beauti
# things ---> thing
# happen ---> happen
# when ---> when
# you ---> you
# distance ---> distanc
# yourself ---> yourself
# from ---> from
# negativity ---> neg
# Whoever ---> whoever
# is ---> is
# trying ---> tri
# to ---> to
# bring ---> bring
# you ---> you
# down ---> down
# is ---> is
# already ---> alreadi
# below ---> below
# you ---> you
# Listening ---> listen
# to ---> to
# music ---> music
# at ---> at
# high ---> high
# volumes ---> volum
# makes ---> make
# a ---> a
# person ---> person
# calmer ---> calmer
# happier ---> happier
# and ---> and
# more ---> more
# relaxed ---> relax
# Train ---> train
# your ---> your
# mind ---> mind
# to ---> to
# see ---> see
# the ---> the
# good ---> good
# in ---> in
# everything ---> everyth
# Life ---> life
# is ---> is
# not ---> not
# about ---> about
# the ---> the
# people ---> peopl
# who ---> who
# act ---> act
# true ---> true
# to ---> to
# your ---> your
# face ---> face
# It ---> it
# about ---> about
# the ---> the
# people ---> peopl
# who ---> who
# remain ---> remain
# true ---> true
# behind ---> behind
# your ---> your
# back ---> back
# It ---> it
# simple ---> simpl
# do ---> do
# do ---> do
# something ---> someth
# that ---> that
# you ---> you
# would ---> would
# want ---> want
# done ---> done
# to ---> to
# you ---> you
# Your ---> your
# memory ---> memori
# will ---> will
# be ---> be
# my ---> my
# last ---> last
# You ---> you
# needed ---> need
# me ---> me
# I ---> i
# was ---> wa
# there ---> there
# I ---> i
# needed ---> need
# you ---> you
# and ---> and
# suddenly ---> suddenli
# you ---> you
# were ---> were
# always ---> alway
# busy ---> busi
# Sometimes ---> sometim
# silence ---> silenc
# hurts ---> hurt
# more ---> more
# than ---> than
# words ---> word
# ever ---> ever
# will ---> will
# No ---> no
# texts ---> text
# no ---> no
# calls ---> call
# nothing ---> noth
# But ---> but
# I ---> i
# still ---> still
# here ---> here
# thinking ---> think
# about ---> about
# you ---> you
# like ---> like
# crazy ---> crazi
# Being ---> be
# single ---> singl
# is ---> is
# better ---> better
# than ---> than
# being ---> be
# in ---> in
# the ---> the
# lie ---> lie
# relationship ---> relationship
# Never ---> never
# get ---> get
# too ---> too
# attached ---> attach
# to ---> to
# something ---> someth
# that ---> that
# is ---> is
# yours ---> your
# Sometimes ---> sometim
# you ---> you
# wish ---> wish
# you ---> you
# could ---> could
# delete ---> delet
# feelings ---> feel
# the ---> the
# way ---> way
# you ---> you
# delete ---> delet
# text ---> text
# messages ---> messag
# FACT ---> fact
# I ---> i
# love ---> love
# buying ---> buy
# new ---> new
# things ---> thing
# but ---> but
# I ---> i
# hate ---> hate
# spending ---> spend
# money ---> money
# I ---> i
# understand ---> understand
# that ---> that
# nobody ---> nobodi
# understands ---> understand
# me ---> me
# but ---> but
# I ---> i
# ca ---> ca
# be ---> be
# someone ---> someon
# I ---> i
# not ---> not
# Do ---> do
# chase ---> chase
# other ---> other
# people ---> peopl
# Work ---> work
# hard ---> hard
# and ---> and
# be ---> be
# yourself ---> yourself
# Under ---> under
# these ---> these
# two ---> two
# principles ---> principl
# the ---> the
# right ---> right
# people ---> peopl
# will ---> will
# find ---> find
# their ---> their
# way ---> way
# into ---> into
# your ---> your
# life ---> life
# If ---> if
# I ---> i
# did ---> did
# care ---> care
# I ---> i
# would ---> would
# have ---> have
# stuck ---> stuck
# around ---> around
# as ---> as
# long ---> long
# as ---> as
# I ---> i
# did ---> did
# Never ---> never
# expect ---> expect
# things ---> thing
# to ---> to
# happen ---> happen
# it ---> it
# better ---> better
# to ---> to
# feel ---> feel
# surprised ---> surpris
# than ---> than
# to ---> to
# feel ---> feel
# disappointed ---> disappoint
# Just ---> just
# because ---> becaus
# it ---> it
# not ---> not
# happening ---> happen
# right ---> right
# now ---> now
# does ---> doe
# mean ---> mean
# it ---> it
# never ---> never
# will ---> will
# Loyalty ---> loyalti
# is ---> is
# everything ---> everyth
# Sometimes ---> sometim
# having ---> have
# some ---> some
# space ---> space
# is ---> is
# what ---> what
# you ---> you
# need ---> need
# to ---> to
# realize ---> realiz
# what ---> what
# you ---> you
# really ---> realli
# want ---> want
# Sometimes ---> sometim
# you ---> you
# ca ---> ca
# even ---> even
# explain ---> explain
# what ---> what
# you ---> you
# feel ---> feel
# for ---> for
# a ---> a
# person ---> person
# I ---> i
# wish ---> wish
# I ---> i
# could ---> could
# download ---> download
# money ---> money
# Ca ---> ca
# delete ---> delet
# feelings ---> feel
# please ---> pleas
# try ---> tri
# again ---> again
# later ---> later
# People ---> peopl
# come ---> come
# and ---> and
# go ---> go
# but ---> but
# life ---> life
# is ---> is
# simply ---> simpli
# about ---> about
# seeing ---> see
# who ---> who
# cares ---> care
# enough ---> enough
# to ---> to
# stay ---> stay
# Be ---> be
# patient ---> patient
# Good ---> good
# things ---> thing
# come ---> come
# to ---> to
# ...
# to ---> to
# smile ---> smile
# instead ---> instead
# Everyone ---> everyon
# makes ---> make
# mistakes ---> mistak
# nobody ---> nobodi
# is ---> is
# perfect ---> perfect
# Live ---> live
# it ---> it
# learn ---> learn
# from ---> from
# it ---> it
# move ---> move
# on ---> on
# True ---> true
# love ---> love
# never ---> never
# fades ---> fade
# Believe ---> believ
# that ---> that
# life ---> life
# is ---> is
# worth ---> worth
# living ---> live
# and ---> and
# your ---> your
# belief ---> belief
# will ---> will
# help ---> help
# create ---> creat
# the ---> the
# fact ---> fact
# What ---> what
# if ---> if
# my ---> my
# dog ---> dog
# only ---> onli
# brings ---> bring
# back ---> back
# the ---> the
# ball ---> ball
# because ---> becaus
# he ---> he
# thinks ---> think
# I ---> i
# like ---> like
# throwing ---> throw
# it ---> it
# Do ---> do
# let ---> let
# yourself ---> yourself
# be ---> be
# controlled ---> control
# by ---> by
# three ---> three
# things ---> thing
# people ---> peopl
# money ---> money
# or ---> or
# past ---> past
# experiences ---> experi
# Take ---> take
# care ---> care
# of ---> of
# yourself ---> yourself
# you ---> you
# all ---> all
# you ---> you
# have ---> have
# Just ---> just
# because ---> becaus
# I ---> i
# did ---> did
# make ---> make
# a ---> a
# move ---> move
# does ---> doe
# mean ---> mean
# I ---> i
# do ---> do
# like ---> like
# you ---> you
# No ---> no
# matter ---> matter
# how ---> how
# strong ---> strong
# I ---> i
# am ---> am
# I ---> i
# always ---> alway
# have ---> have
# limit ---> limit
# The ---> the
# person ---> person
# you ---> you
# took ---> took
# for ---> for
# granted ---> grant
# today ---> today
# may ---> may
# turn ---> turn
# out ---> out
# to ---> to
# be ---> be
# the ---> the
# person ---> person
# you ---> you
# need ---> need
# tomorrow ---> tomorrow
# please ---> pleas
# do ---> do
# underestimate ---> underestim
# my ---> my
# ability ---> abil
# to ---> to
# drop ---> drop
# you ---> you
# When ---> when
# you ---> you
# become ---> becom
# really ---> realli
# close ---> close
# to ---> to
# someone ---> someon
# you ---> you
# can ---> can
# hear ---> hear
# their ---> their
# voice ---> voic
# in ---> in
# your ---> your
# head ---> head
# when ---> when
# you ---> you
# read ---> read
# their ---> their
# texts ---> text
# Do ---> do
# give ---> give
# up ---> up
# great ---> great
# things ---> thing
# take ---> take
# time ---> time
# The ---> the
# pain ---> pain
# of ---> of
# today ---> today
# is ---> is
# the ---> the
# strength ---> strength
# of ---> of
# tomorrow ---> tomorrow
# Dear ---> dear
# heart ---> heart
# please ---> pleas
# stop ---> stop
# falling ---> fall
# in ---> in
# love ---> love
# with ---> with
# people ---> peopl
# I ---> i
# ca ---> ca
# have ---> have
# If ---> if
# tomato ---> tomato
# is ---> is
# a ---> a
# fruit ---> fruit
# then ---> then
# is ---> is
# ketchup ---> ketchup
# a ---> a
# smoothie ---> smoothi
# It ---> it
# does ---> doe
# matter ---> matter
# what ---> what
# people ---> peopl
# say ---> say
# be ---> be
# yourself ---> yourself
# What ---> what
# if ---> if
# your ---> your
# life ---> life
# flashing ---> flash
# before ---> befor
# your ---> your
# eyes ---> eye
# is ---> is
# actually ---> actual
# your ---> your
# brain ---> brain
# going ---> go
# through ---> through
# your ---> your
# history ---> histori
# to ---> to
# see ---> see
# if ---> if
# there ---> there
# is ---> is
# a ---> a
# way ---> way
# to ---> to
# keep ---> keep
# you ---> you
# alive ---> aliv
# My ---> my
# hair ---> hair
# is ---> is
# naturally ---> natur
# curly ---> curli
# or ---> or
# straight ---> straight
# It ---> it
# like ---> like
# the ---> the
# awkward ---> awkward
# stage ---> stage
# between ---> between
# curly ---> curli
# and ---> and
# straight ---> straight
# where ---> where
# I ---> i
# ca ---> ca
# leave ---> leav
# it ---> it
# natural ---> natur
# You ---> you
# never ---> never
# know ---> know
# how ---> how
# strong ---> strong
# you ---> you
# are ---> are
# until ---> until
# being ---> be
# strong ---> strong
# is ---> is
# the ---> the
# only ---> onli
# choice ---> choic
# you ---> you
# have ---> have
# Someone ---> someon
# who ---> who
# truly ---> truli
# loves ---> love
# you ---> you
# will ---> will
# chase ---> chase
# after ---> after
# you ---> you
# no ---> no
# matter ---> matter
# what ---> what
# let ---> let
# the ---> the
# rain ---> rain
# wash ---> wash
# away ---> away
# all ---> all
# the ---> the
# pain ---> pain
# of ---> of
# yesterday ---> yesterday
# I ---> i
# feel ---> feel
# really ---> realli
# happy ---> happi
# when ---> when
# I ---> i
# see ---> see
# you ---> you
# I ---> i
# young ---> young
# but ---> but
# I ---> i
# been ---> been
# through ---> through
# a ---> a
# lot ---> lot
# Give ---> give
# yourself ---> yourself
# a ---> a
# break ---> break
# Do ---> do
# stress ---> stress
# too ---> too
# much ---> much
# I ---> i
# think ---> think
# one ---> one
# of ---> of
# the ---> the
# greatest ---> greatest
# feelings ---> feel
# is ---> is
# when ---> when
# someone ---> someon
# openly ---> openli
# tells ---> tell
# you ---> you
# how ---> how
# much ---> much
# you ---> you
# mean ---> mean
# to ---> to
# them ---> them
# randomly ---> randomli
# sometimes ---> sometim
# it ---> it
# better ---> better
# to ---> to
# be ---> be
# alone ---> alon
# nobody ---> nobodi
# can ---> can
# hurt ---> hurt
# you ---> you
# Sometimes ---> sometim
# I ---> i
# keep ---> keep
# my ---> my
# feelings ---> feel
# to ---> to
# myself ---> myself
# because ---> becaus
# its ---> it
# hard ---> hard
# to ---> to
# find ---> find
# someone ---> someon
# who ---> who
# understands ---> understand
# Smile ---> smile
# because ---> becaus
# life ---> life
# is ---> is
# too ---> too
# short ---> short
# to ---> to
# be ---> be
# unhappy ---> unhappi
# I ---> i
# ca ---> ca
# promise ---> promis
# that ---> that
# things ---> thing
# will ---> will
# be ---> be
# perfect ---> perfect
# but ---> but
# I ---> i
# swear ---> swear
# I ---> i
# never ---> never
# leave ---> leav
# You ---> you
# her ---> her
# boyfriend ---> boyfriend
# If ---> if
# she ---> she
# crying ---> cri
# hold ---> hold
# her ---> her
# You ---> you
# do ---> do
# need ---> need
# to ---> to
# say ---> say
# a ---> a
# thing ---> thing
# Just ---> just
# comfort ---> comfort
# her ---> her
# until ---> until
# she ---> she
# okay ---> okay
# It ---> it
# painful ---> pain
# to ---> to
# say ---> say
# goodbye ---> goodby
# to ---> to
# someone ---> someon
# you ---> you
# do ---> do
# want ---> want
# to ---> to
# let ---> let
# go ---> go
# but ---> but
# more ---> more
# painful ---> pain
# to ---> to
# ask ---> ask
# someone ---> someon
# to ---> to
# stay ---> stay
# when ---> when
# you ---> you
# know ---> know
# they ---> they
# want ---> want
# to ---> to
# leave ---> leav
# Life ---> life
# is ---> is
# better ---> better
# when ---> when
# you ---> you
# laughing ---> laugh
# i ---> i
# wish ---> wish
# my ---> my
# mind ---> mind
# had ---> had
# a ---> a
# control ---> control
# button ---> button
# I ---> i
# want ---> want
# to ---> to
# stop ---> stop
# over ---> over
# thinking ---> think
# everything ---> everyth
# If ---> if
# I ---> i
# want ---> want
# you ---> you
# do ---> do
# worry ---> worri
# about ---> about
# who ---> who
# wants ---> want
# me ---> me
# Fuck ---> fuck
# everyone ---> everyon
# who ---> who
# said ---> said
# they ---> they
# were ---> were
# there ---> there
# for ---> for
# me ---> me
# and ---> and
# then ---> then
# left ---> left
# Sometimes ---> sometim
# you ---> you
# just ---> just
# need ---> need
# to ---> to
# wait ---> wait
# and ---> and
# pray ---> pray
# Be ---> be
# proud ---> proud
# of ---> of
# yourself ---> yourself
# for ---> for
# how ---> how
# far ---> far
# you ---> you
# have ---> have
# come ---> come
# and ---> and
# never ---> never
# stop ---> stop
# pushing ---> push
# to ---> to
# be ---> be
# the ---> the
# best ---> best
# you ---> you
# can ---> can
# be ---> be
# i ---> i
# always ---> alway
# here ---> here
# for ---> for
# you ---> you
# but ---> but
# you ---> you
# not ---> not
# What ---> what
# hurts ---> hurt
# you ---> you
# today ---> today
# makes ---> make
# you ---> you
# stronger ---> stronger
# tomorrow ---> tomorrow
# Do ---> do
# ignore ---> ignor
# me ---> me
# for ---> for
# days ---> day
# and ---> and
# then ---> then
# start ---> start
# talking ---> talk
# to ---> to
# me ---> me
# again ---> again
# like ---> like
# nothing ---> noth
# happened ---> happen
# You ---> you
# gon ---> gon
# na ---> na
# miss ---> miss
# me ---> me
# when ---> when
# i ---> i
# gone ---> gone
# I ---> i
# want ---> want
# to ---> to
# tell ---> tell
# you ---> you
# I ---> i
# love ---> love
# you ---> you
# because ---> becaus
# I ---> i
# do ---> do
# I ---> i
# just ---> just
# scared ---> scare
# what ---> what
# your ---> your
# response ---> respons
# will ---> will
# be ---> be
# Never ---> never
# forget ---> forget
# how ---> how
# blessed ---> bless
# you ---> you
# are ---> are
# Do ---> do
# be ---> be
# negative ---> neg
# when ---> when
# you ---> you
# have ---> have
# so ---> so
# much ---> much
# to ---> to
# be ---> be
# positive ---> posit
# about ---> about
# I ---> i
# do ---> do
# understand ---> understand
# how ---> how
# someone ---> someon
# can ---> can
# tell ---> tell
# so ---> so
# many ---> mani
# lies ---> lie
# never ---> never
# feel ---> feel
# bad ---> bad
# about ---> about
# it ---> it
# Sometimes ---> sometim
# it ---> it
# s ---> s
# better ---> better
# to ---> to
# react ---> react
# with ---> with
# no ---> no
# reaction ---> reaction
# One ---> one
# of ---> of
# the ---> the
# saddest ---> saddest
# things ---> thing
# in ---> in
# life ---> life
# is ---> is
# loving ---> love
# someone ---> someon
# who ---> who
# used ---> use
# to ---> to
# love ---> love
# you ---> you
# When ---> when
# you ---> you
# young ---> young
# everything ---> everyth
# feels ---> feel
# like ---> like
# the ---> the
# end ---> end
# of ---> of
# the ---> the
# world ---> world
# But ---> but
# it ---> it
# not ---> not
# it ---> it
# just ---> just
# the ---> the
# beginning ---> begin
# Your ---> your
# future ---> futur
# depends ---> depend
# on ---> on
# many ---> mani
# things ---> thing
# but ---> but
# mostly ---> mostli
# on ---> on
# you ---> you
# Why ---> whi
# do ---> do
# I ---> i
# feel ---> feel
# so ---> so
# alone ---> alon
# No ---> no
# matter ---> matter
# how ---> how
# educated ---> educ
# talented ---> talent
# rich ---> rich
# or ---> or
# cool ---> cool
# you ---> you
# believe ---> believ
# you ---> you
# are ---> are
# how ---> how
# you ---> you
# treat ---> treat
# people ---> peopl
# ultimately ---> ultim
# tells ---> tell
# all ---> all
# Look ---> look
# for ---> for
# something ---> someth
# positive ---> posit
# in ---> in
# each ---> each
# day ---> day
# even ---> even
# if ---> if
# some ---> some
# days ---> day
# you ---> you
# have ---> have
# to ---> to
# look ---> look
# a ---> a
# little ---> littl
# harder ---> harder
# Real ---> real
# friends ---> friend
# get ---> get
# treated ---> treat
# like ---> like
# family ---> famili
# Do ---> do
# be ---> be
# afraid ---> afraid
# of ---> of
# being ---> be
# different ---> differ
# Be ---> be
# afraid ---> afraid
# of ---> of
# being ---> be
# the ---> the
# same ---> same
# as ---> as
# everyone ---> everyon
# else ---> els
# I ---> i
# sensitive ---> sensit
# I ---> i
# overthink ---> overthink
# every ---> everi
# little ---> littl
# thing ---> thing
# and ---> and
# I ---> i
# care ---> care
# way ---> way
# too ---> too
# much ---> much
# I ---> i
# love ---> love
# you ---> you
# I ---> i
# know ---> know
# you ---> you
# do ---> do
# feel ---> feel
# the ---> the
# same ---> same
# to ---> to
# me ---> me
# but ---> but
# I ---> i
# just ---> just
# wanted ---> want
# to ---> to
# let ---> let
# you ---> you
# know ---> know
# how ---> how
# I ---> i
# feel ---> feel
# Can ---> can
# I ---> i
# skip ---> skip
# the ---> the
# studying ---> studi
# part ---> part
# and ---> and
# just ---> just
# travel ---> travel
# Thanks ---> thank
# What ---> what
# makes ---> make
# a ---> a
# girl ---> girl
# beautiful ---> beauti
# is ---> is
# her ---> her
# simplicity ---> simplic
# Listen ---> listen
# to ---> to
# the ---> the
# advice ---> advic
# of ---> of
# older ---> older
# people ---> peopl
# Not ---> not
# because ---> becaus
# they ---> they
# right ---> right
# but ---> but
# because ---> becaus
# they ---> they
# have ---> have
# the ---> the
# most ---> most
# experience ---> experi
# being ---> be
# wrong ---> wrong
# When ---> when
# you ---> you
# say ---> say
# or ---> or
# your ---> your
# lips ---> lip
# move ---> move
# in ---> in
# those ---> those
# directions ---> direct
# Loyalty ---> loyalti
# is ---> is
# everything ---> everyth
# No ---> no
# matter ---> matter
# how ---> how
# much ---> much
# you ---> you
# have ---> have
# changed ---> chang
# I ---> i
# still ---> still
# remember ---> rememb
# the ---> the
# old ---> old
# you ---> you
# Stop ---> stop
# looking ---> look
# for ---> for
# reasons ---> reason
# to ---> to
# be ---> be
# unhappy ---> unhappi
# Focus ---> focu
# on ---> on
# the ---> the
# things ---> thing
# you ---> you
# do ---> do
# have ---> have
# and ---> and
# the ---> the
# reasons ---> reason
# you ---> you
# should ---> should
# be ---> be
# happy ---> happi
# Work ---> work
# hard ---> hard
# Stay ---> stay
# humble ---> humbl
# Dream ---> dream
# big ---> big
# Accept ---> accept
# what ---> what
# is ---> is
# let ---> let
# go ---> go
# of ---> of
# what ---> what
# was ---> wa
# have ---> have
# faith ---> faith
# in ---> in
# what ---> what
# will ---> will
# be ---> be
# The ---> the
# longer ---> longer
# you ---> you
# hide ---> hide
# your ---> your
# feelings ---> feel
# for ---> for
# someone ---> someon
# the ---> the
# more ---> more
# you ---> you
# fall ---> fall
# for ---> for
# them ---> them
# My ---> my
# life ---> life
# is ---> is
# perfect ---> perfect
# but ---> but
# I ---> i
# thankful ---> thank
# for ---> for
# everything ---> everyth
# I ---> i
# have ---> have
# Avocados ---> avocado
# raspberries ---> raspberri
# almonds ---> almond
# broccoli ---> broccoli
# spinach ---> spinach
# salmon ---> salmon
# are ---> are
# among ---> among
# the ---> the
# healthiest ---> healthiest
# foods ---> food
# on ---> on
# the ---> the
# planet ---> planet
# Do ---> do
# not ---> not
# lock ---> lock
# yourself ---> yourself
# in ---> in
# just ---> just
# one ---> one
# book ---> book
# Behind ---> behind
# every ---> everi
# beautiful ---> beauti
# girl ---> girl
# there ---> there
# a ---> a
# dumbass ---> dumbass
# guy ---> guy
# who ---> who
# did ---> did
# her ---> her
# wrong ---> wrong
# and ---> and
# made ---> made
# her ---> her
# strong ---> strong
# If ---> if
# it ---> it
# does ---> doe
# open ---> open
# it ---> it
# not ---> not
# your ---> your
# door ---> door
# Beauty ---> beauti
# is ---> is
# not ---> not
# in ---> in
# the ---> the
# face ---> face
# beauty ---> beauti
# is ---> is
# a ---> a
# light ---> light
# in ---> in
# the ---> the
# heart ---> heart
# Never ---> never
# give ---> give
# up ---> up
# on ---> on
# someone ---> someon
# you ---> you
# ca ---> ca
# go ---> go
# a ---> a
# day ---> day
# without ---> without
# thinking ---> think
# about ---> about
# Every ---> everi
# pain ---> pain
# gives ---> give
# a ---> a
# lesson ---> lesson
# and ---> and
# every ---> everi
# lesson ---> lesson
# changes ---> chang
# a ---> a
# person ---> person
# Do ---> do
# give ---> give
# up ---> up
# on ---> on
# things ---> thing
# that ---> that
# make ---> make
# you ---> you
# smile ---> smile
# Even ---> even
# the ---> the
# strongest ---> strongest
# can ---> can
# be ---> be
# broken ---> broken
# God ---> god
# always ---> alway
# gives ---> give
# us ---> us
# unexpected ---> unexpect
# blessings ---> bless
# It ---> it
# sucks ---> suck
# to ---> to
# know ---> know
# you ---> you
# still ---> still
# love ---> love
# the ---> the
# person ---> person
# who ---> who
# broke ---> broke
# your ---> your
# heart ---> heart
# If ---> if
# you ---> you
# do ---> do
# fight ---> fight
# for ---> for
# what ---> what
# you ---> you
# want ---> want
# do ---> do
# cry ---> cri
# for ---> for
# what ---> what
# you ---> you
# lost ---> lost
# If ---> if
# you ---> you
# love ---> love
# something ---> someth
# set ---> set
# it ---> it
# free ---> free
# if ---> if
# it ---> it
# comes ---> come
# back ---> back
# it ---> it
# yours ---> your
# if ---> if
# it ---> it
# does ---> doe
# it ---> it
# never ---> never
# was ---> wa
# I ---> i
# hate ---> hate
# texting ---> text
# you ---> you
# first ---> first
# it ---> it
# makes ---> make
# me ---> me
# feel ---> feel
# like ---> like
# i ---> i
# annoying ---> annoy
# you ---> you
# Before ---> befor
# you ---> you
# give ---> give
# up ---> up
# Think ---> think
# about ---> about
# why ---> whi
# you ---> you
# held ---> held
# on ---> on
# for ---> for
# so ---> so
# long ---> long
# The ---> the
# number ---> number
# of ---> of
# you ---> you
# have ---> have
# does ---> doe
# not ---> not
# make ---> make
# you ---> you
# better ---> better
# than ---> than
# anyone ---> anyon
# else ---> els
# Hitler ---> hitler
# had ---> had
# millions ---> million
# and ---> and
# Jesus ---> jesu
# had ---> had
# I ---> i
# want ---> want
# to ---> to
# be ---> be
# the ---> the
# person ---> person
# you ---> you
# scared ---> scare
# to ---> to
# lose ---> lose
# Patience ---> patienc
# is ---> is
# not ---> not
# the ---> the
# ability ---> abil
# to ---> to
# wait ---> wait
# but ---> but
# how ---> how
# you ---> you
# act ---> act
# while ---> while
# you ---> you
# waiting ---> wait
# Life ---> life
# is ---> is
# like ---> like
# a ---> a
# book ---> book
# If ---> if
# you ---> you
